# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from ks_metric import ks_table, ks_score

data = load_breast_cancer()
X, y = data['data'], data['target']
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

clf = LogisticRegression(random_state=0, max_iter=10000).fit(X_train, y_train)

# %%
train_ks_table = ks_table(y_train, clf.predict_proba(X_train)[:,1])
test_ks_table = ks_table(y_test, clf.predict_proba(X_test)[:,1])

display(train_ks_table, test_ks_table)
# Out:
#       min_score  max_score  n_bads  n_goods  n_total  odds bad_rate good_rate  \
# 0  8.208936e-38   0.000001       0       39       39   inf    0.00%   100.00%
# 1  1.151524e-06   0.000548       0       38       38   inf    0.00%   100.00%
# 2  7.493519e-04   0.058830       0       38       38   inf    0.00%   100.00%
# 3  6.508148e-02   0.702489      11       27       38  2.45   28.95%    71.05%
# 4  7.115338e-01   0.956230      36        2       38  0.06   94.74%     5.26%
# 5  9.572268e-01   0.988154      37        1       38  0.03   97.37%     2.63%
# 6  9.898127e-01   0.997348      38        0       38  0.00  100.00%     0.00%
# 7  9.973934e-01   0.999438      38        0       38  0.00  100.00%     0.00%
# 8  9.994476e-01   0.999890      38        0       38  0.00  100.00%     0.00%
# 9  9.998948e-01   0.999999      38        0       38  0.00  100.00%     0.00%
#
#   cs_bads cs_goods    sep   KS
# 0    0.00    26.90  26.90
# 1    0.00    53.10  53.10
# 2    0.00    79.31  79.31
# 3    4.66    97.93  93.27  <--
# 4   19.92    99.31  79.40
# 5   35.59   100.00  64.41
# 6   51.69   100.00  48.31
# 7   67.80   100.00  32.20
# 8   83.90   100.00  16.10
# 9  100.00   100.00   0.00
#       min_score     max_score  n_bads  n_goods  n_total  odds bad_rate  \
# 0  1.308217e-22  1.583406e-07       0       19       19   inf    0.00%
# 1  2.179848e-07  4.674545e-04       0       19       19   inf    0.00%
# 2  4.866203e-04  1.541071e-02       0       19       19   inf    0.00%
# 3  2.174837e-02  7.713780e-01       9        9       18  1.00   50.00%
# 4  7.797934e-01  9.657101e-01      18        1       19  0.06   94.74%
# 5  9.714859e-01  9.903406e-01      19        0       19  0.00  100.00%
# 6  9.930026e-01  9.977953e-01      18        0       18  0.00  100.00%
# 7  9.979159e-01  9.992914e-01      19        0       19  0.00  100.00%
# 8  9.992922e-01  9.998013e-01      19        0       19  0.00  100.00%
# 9  9.998073e-01  1.000000e+00      19        0       19  0.00  100.00%
#
#   good_rate cs_bads cs_goods    sep   KS
# 0   100.00%    0.00    28.36  28.36
# 1   100.00%    0.00    56.72  56.72
# 2   100.00%    0.00    85.07  85.07
# 3    50.00%    7.44    98.51  91.07  <--
# 4     5.26%   22.31   100.00  77.69
# 5     0.00%   38.02   100.00  61.98
# 6     0.00%   52.89   100.00  47.11
# 7     0.00%   68.60   100.00  31.40
# 8     0.00%   84.30   100.00  15.70
# 9     0.00%  100.00   100.00   0.00
